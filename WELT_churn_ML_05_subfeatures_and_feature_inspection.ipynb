# %% [markdown]
# ## Training des Klassifizierungsmodels und Einsicht in das Model

# %% [markdown]
# Vorher wurde Model und Datensatz klassifiziert, hier werden subsets der Features untersucht wie gut diese eine Vorhersage machen können
#
# - Model ist ein GradientBoost mit 400/800 estimators
# - Data Set sind absolute Click-Zahlen (page impression, visits, visits inculding home pi, usw.), Metrik ist Gauss-basiert
#
# HIER
# - werden verschiedene Untergruppen im Datensatz angeguckt (lange/kurze Verträge, mit/ohne Schläfer usw.)
# - werden Regeln extrahiert, die die Modelle klassifizeren

# %%
import pandas as pd
import pickle
from datetime import datetime
# %pylab inline

dat_all, dat_long, dat_short = pickle.load(open('dat_to_train.pkl','rb'))
dat_all_wBehav, dat_long_wBehav, dat_short_wBehav = pickle.load(open('dat_to_train_wlastBehav.pkl','rb'))
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['datetime']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %% [markdown]
# Vertragslänge ist herovrragender Prediktor für Kündigungswahrscheinlichkeit!
#
# Lange Kunden, die kündigen sind schwer von langen Kunden, die nicht kündigen zu unterscheiden. Auch das Training-Datenset performt nicht optimal.
#
# Nutzerverhalten vorm Kündigen spielt eine untergeordnete Rolle beim Klassifizieren

# %% [markdown]
# ### Training

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import GradientBoostingClassifier
from datetime import datetime

# prepare data
keys = ['dat_all', 'dat_long', 'dat_short', 'dat_all_wBehav', 'dat_long_wBehav', 'dat_short_wBehav']
dats = [dat_all, dat_long, dat_short, dat_all_wBehav, dat_long_wBehav, dat_short_wBehav]

dat_train = {}
dat_test = {}
label_train = {}
label_test = {}
for idx, key in enumerate(keys):
    label = dats[idx]['dat_abs_gauss_final']['Kuendigungsstatus']
    dat_cp = dats[idx]['dat_abs_gauss_final'].drop(columns = ['Kuendigungsstatus'])
    
    dat_train_, dat_test_, label_train_, label_test_ = train_test_split(dat_cp, label, test_size=0.2, random_state=42)
    dat_train[key] = dat_train_
    dat_test[key] = dat_test_
    label_train[key] = label_train_
    label_test[key] = label_test_

# %%
# model training
classifiers = {}
for key in keys:
    
    print(datetime.now().time())
    print(key)

    classifiers[key] = GradientBoostingClassifier( n_estimators = 800 )
    classifiers[key].fit(dat_train[key], label_train[key])
# Out:
# 18:29:29.615357
# dat_all
# 18:29:39.955434
# dat_long
# 18:29:47.789998
# dat_short
# 18:29:50.276349
# dat_all_wBehav
# 18:30:12.373738
# dat_long_wBehav
# 18:30:29.094101
# dat_short_wBehav

# %% [markdown]
# Das Model Training mit den gesetzten Parametern dauert nur Sekunden.

# %% [markdown]
# ### Make Prediction

# %%
from sklearn.metrics import classification_report

pred_train={}
pred_test ={}

for key in keys:
    pred_train[key] = classifiers[key].predict(dat_train[key])
    pred_test[key] = classifiers[key].predict(dat_test[key])

# %%
print('#### Training with n_estimators = 800 ###')

for key in keys:
    print('#########################')
    print(key)
    print('#########################')
    print('TRAINING SET')
    print('')
    print(pd.crosstab(label_train[key], pred_train[key], rownames=['True'], colnames=['Predicted'], margins=True))
    print()
    print(classification_report(label_train[key], pred_train[key]))
    print('#########################')
    print('TEST SET')
    print('')
    print(pd.crosstab(label_test[key], pred_test[key], rownames=['True'], colnames=['Predicted'], margins=True))
    print()
    print(classification_report(label_test[key], pred_test[key]))
# Out:
# #### Training with n_estimators = 800 ###
# #########################
# dat_all
# #########################
# TRAINING SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt          1662            48  1710
# ungekuendigt         713          4401  5114
# All                 2375          4449  6824
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.70      0.97      0.81      1710
# ungekuendigt       0.99      0.86      0.92      5114
#
#  avg / total       0.92      0.89      0.89      6824
#
# #########################
# TEST SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt           359            76   435
# ungekuendigt         227          1044  1271
# All                  586          1120  1706
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.61      0.83      0.70       435
# ungekuendigt       0.93      0.82      0.87      1271
#
#  avg / total       0.85      0.82      0.83      1706
#
# #########################
# dat_long
# #########################
# TRAINING SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt           355           304   659
# ungekuendigt           8          4269  4277
# All                  363          4573  4936
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.98      0.54      0.69       659
# ungekuendigt       0.93      1.00      0.96      4277
#
#  avg / total       0.94      0.94      0.93      4936
#
# #########################
# TEST SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt            36           130   166
# ungekuendigt          28          1041  1069
# All                   64          1171  1235
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.56      0.22      0.31       166
# ungekuendigt       0.89      0.97      0.93      1069
#
#  avg / total       0.85      0.87      0.85      1235
#
# #########################
# dat_short
# #########################
# TRAINING SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt          1058             1  1059
# ungekuendigt          93           735   828
# All                 1151           736  1887
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.92      1.00      0.96      1059
# ungekuendigt       1.00      0.89      0.94       828
#
#  avg / total       0.95      0.95      0.95      1887
#
# #########################
# TEST SET
#
# Predicted     gekuendigt  ungekuendigt  All
# True
# gekuendigt           230            31  261
# ungekuendigt          57           154  211
# All                  287           185  472
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.80      0.88      0.84       261
# ungekuendigt       0.83      0.73      0.78       211
#
#  avg / total       0.82      0.81      0.81       472
#
# #########################
# dat_all_wBehav
# #########################
# TRAINING SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt          1668            42  1710
# ungekuendigt         702          4412  5114
# All                 2370          4454  6824
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.70      0.98      0.82      1710
# ungekuendigt       0.99      0.86      0.92      5114
#
#  avg / total       0.92      0.89      0.90      6824
#
# #########################
# TEST SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt           365            70   435
# ungekuendigt         205          1066  1271
# All                  570          1136  1706
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.64      0.84      0.73       435
# ungekuendigt       0.94      0.84      0.89      1271
#
#  avg / total       0.86      0.84      0.85      1706
#
# #########################
# dat_long_wBehav
# #########################
# TRAINING SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt           354           305   659
# ungekuendigt           8          4269  4277
# All                  362          4574  4936
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.98      0.54      0.69       659
# ungekuendigt       0.93      1.00      0.96      4277
#
#  avg / total       0.94      0.94      0.93      4936
#
# #########################
# TEST SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt            46           120   166
# ungekuendigt          16          1053  1069
# All                   62          1173  1235
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.74      0.28      0.40       166
# ungekuendigt       0.90      0.99      0.94      1069
#
#  avg / total       0.88      0.89      0.87      1235
#
# #########################
# dat_short_wBehav
# #########################
# TRAINING SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt          1058             1  1059
# ungekuendigt          92           736   828
# All                 1150           737  1887
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.92      1.00      0.96      1059
# ungekuendigt       1.00      0.89      0.94       828
#
#  avg / total       0.95      0.95      0.95      1887
#
# #########################
# TEST SET
#
# Predicted     gekuendigt  ungekuendigt  All
# True
# gekuendigt           240            21  261
# ungekuendigt          49           162  211
# All                  289           183  472
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.83      0.92      0.87       261
# ungekuendigt       0.89      0.77      0.82       211
#
#  avg / total       0.85      0.85      0.85       472

# %%
print('#### Training with n_estimators = 400 ###')

for key in keys:
    print('#########################')
    print(key)
    print('#########################')
    print('TRAINING SET')
    print('')
    print(pd.crosstab(label_train[key], pred_train[key], rownames=['True'], colnames=['Predicted'], margins=True))
    print()
    print(classification_report(label_train[key], pred_train[key]))
    print('#########################')
    print('TEST SET')
    print('')
    print(pd.crosstab(label_test[key], pred_test[key], rownames=['True'], colnames=['Predicted'], margins=True))
    print()
    print(classification_report(label_test[key], pred_test[key]))
# Out:
# #### Training with n_estimators = 400 ###
# #########################
# dat_all
# #########################
# TRAINING SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt          1577           133  1710
# ungekuendigt         754          4360  5114
# All                 2331          4493  6824
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.68      0.92      0.78      1710
# ungekuendigt       0.97      0.85      0.91      5114
#
#  avg / total       0.90      0.87      0.88      6824
#
# #########################
# TEST SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt           362            73   435
# ungekuendigt         219          1052  1271
# All                  581          1125  1706
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.62      0.83      0.71       435
# ungekuendigt       0.94      0.83      0.88      1271
#
#  avg / total       0.86      0.83      0.84      1706
#
# #########################
# dat_long
# #########################
# TRAINING SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt           330           329   659
# ungekuendigt          17          4260  4277
# All                  347          4589  4936
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.95      0.50      0.66       659
# ungekuendigt       0.93      1.00      0.96      4277
#
#  avg / total       0.93      0.93      0.92      4936
#
# #########################
# TEST SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt            38           128   166
# ungekuendigt          28          1041  1069
# All                   66          1169  1235
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.58      0.23      0.33       166
# ungekuendigt       0.89      0.97      0.93      1069
#
#  avg / total       0.85      0.87      0.85      1235
#
# #########################
# dat_short
# #########################
# TRAINING SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt          1051             8  1059
# ungekuendigt         102           726   828
# All                 1153           734  1887
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.91      0.99      0.95      1059
# ungekuendigt       0.99      0.88      0.93       828
#
#  avg / total       0.95      0.94      0.94      1887
#
# #########################
# TEST SET
#
# Predicted     gekuendigt  ungekuendigt  All
# True
# gekuendigt           233            28  261
# ungekuendigt          58           153  211
# All                  291           181  472
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.80      0.89      0.84       261
# ungekuendigt       0.85      0.73      0.78       211
#
#  avg / total       0.82      0.82      0.82       472
#
# #########################
# dat_all_wBehav
# #########################
# TRAINING SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt          1619            91  1710
# ungekuendigt         717          4397  5114
# All                 2336          4488  6824
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.69      0.95      0.80      1710
# ungekuendigt       0.98      0.86      0.92      5114
#
#  avg / total       0.91      0.88      0.89      6824
#
# #########################
# TEST SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt           362            73   435
# ungekuendigt         200          1071  1271
# All                  562          1144  1706
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.64      0.83      0.73       435
# ungekuendigt       0.94      0.84      0.89      1271
#
#  avg / total       0.86      0.84      0.85      1706
#
# #########################
# dat_long_wBehav
# #########################
# TRAINING SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt           325           334   659
# ungekuendigt          16          4261  4277
# All                  341          4595  4936
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.95      0.49      0.65       659
# ungekuendigt       0.93      1.00      0.96      4277
#
#  avg / total       0.93      0.93      0.92      4936
#
# #########################
# TEST SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt            50           116   166
# ungekuendigt          16          1053  1069
# All                   66          1169  1235
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.76      0.30      0.43       166
# ungekuendigt       0.90      0.99      0.94      1069
#
#  avg / total       0.88      0.89      0.87      1235
#
# #########################
# dat_short_wBehav
# #########################
# TRAINING SET
#
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt          1052             7  1059
# ungekuendigt          99           729   828
# All                 1151           736  1887
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.91      0.99      0.95      1059
# ungekuendigt       0.99      0.88      0.93       828
#
#  avg / total       0.95      0.94      0.94      1887
#
# #########################
# TEST SET
#
# Predicted     gekuendigt  ungekuendigt  All
# True
# gekuendigt           240            21  261
# ungekuendigt          50           161  211
# All                  290           182  472
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.83      0.92      0.87       261
# ungekuendigt       0.88      0.76      0.82       211
#
#  avg / total       0.85      0.85      0.85       472

# %% [markdown]
# ##### With Vertragslänge

# %%
print(pd.crosstab(label_train_vl, pred_vl, rownames=['True'], colnames=['Predicted'], margins=True))
print()
print(classification_report(label_train_vl, pred_vl))
# Out:
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt          1693            17  1710
# ungekuendigt           7          5107  5114
# All                 1700          5124  6824
#
#               precision    recall  f1-score   support
#
#   gekuendigt       1.00      0.99      0.99      1710
# ungekuendigt       1.00      1.00      1.00      5114
#
#  avg / total       1.00      1.00      1.00      6824

# %% [markdown]
# ##### Ohne Vertragslaenge

# %%
print(pd.crosstab(label_train, pred, rownames=['True'], colnames=['Predicted'], margins=True))
print()
print(classification_report(label_train, pred))
# Out:
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt          1560           150  1710
# ungekuendigt         751          4363  5114
# All                 2311          4513  6824
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.68      0.91      0.78      1710
# ungekuendigt       0.97      0.85      0.91      5114
#
#  avg / total       0.89      0.87      0.87      6824

# %% [markdown]
# ##### Kurze Verträge

# %%
print(pd.crosstab(label_short_train, pred_short, rownames=['True'], colnames=['Predicted'], margins=True))
print()
print(classification_report(label_short_train, pred_short))
# Out:
# Predicted     gekuendigt  ungekuendigt   All
# True
# gekuendigt          1050             9  1059
# ungekuendigt         100           728   828
# All                 1150           737  1887
#
#               precision    recall  f1-score   support
#
#   gekuendigt       0.91      0.99      0.95      1059
# ungekuendigt       0.99      0.88      0.93       828
#
#  avg / total       0.95      0.94      0.94      1887

# %% [markdown]
# ##### Lange Verträge

# %%
print(pd.crosstab(label_long_test, pred_long, rownames=['True'], colnames=['Predicted'], margins=True))
print()
print(classification_report(label_long_test, pred_long))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-26-8b23b3be3130> in <module>()
# ----> 1 print(pd.crosstab(label_long_test, pred_long, rownames=['True'], colnames=['Predicted'], margins=True))
#       2 print()
#       3 print(classification_report(label_long_test, pred_long))
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/reshape/pivot.py in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     464
#     465     from pandas import DataFrame
# --> 466     df = DataFrame(data, index=common_idx)
#     467     if values is None:
#     468         df['__dummy__'] = 0
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in __init__(self, data, index, columns, dtype, copy)
#     346                                  dtype=dtype, copy=copy)
#     347         elif isinstance(data, dict):
# --> 348             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     349         elif isinstance(data, ma.MaskedArray):
#     350             import numpy.ma.mrecords as mrecords
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _init_dict(self, data, index, columns, dtype)
#     457             arrays = [data[k] for k in keys]
#     458
# --> 459         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     460
#     461     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    7321     axes = [_ensure_index(columns), _ensure_index(index)]
#    7322
# -> 7323     return create_block_manager_from_arrays(arrays, arr_names, axes)
#    7324
#    7325
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4875         return mgr
#    4876     except ValueError as e:
# -> 4877         construction_error(len(arrays), arrays[0].shape, axes, e)
#    4878
#    4879
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in construction_error(tot_items, block_shape, axes, e)
#    4837     implied = tuple(map(int, [len(ax) for ax in axes]))
#    4838     if passed == implied and e is not None:
# -> 4839         raise e
#    4840     if block_shape[0] == 0:
#    4841         raise ValueError("Empty data passed with indices specified.")
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in create_block_manager_from_arrays(arrays, names, axes)
#    4870
#    4871     try:
# -> 4872         blocks = form_blocks(arrays, names, axes)
#    4873         mgr = BlockManager(blocks, axes)
#    4874         mgr._consolidate_inplace()
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in form_blocks(arrays, names, axes)
#    4936
#    4937     if len(items_dict['ObjectBlock']) > 0:
# -> 4938         object_blocks = _simple_blockify(items_dict['ObjectBlock'], np.object_)
#    4939         blocks.extend(object_blocks)
#    4940
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in _simple_blockify(tuples, dtype)
#    4974     not None, coerce to this dtype
#    4975     """
# -> 4976     values, placement = _stack_arrays(tuples, dtype)
#    4977
#    4978     # CHECK DTYPE?
#
# /Library/Frameworks/Python.framework/Versions/3.6/lib/python3.6/site-packages/pandas/core/internals.py in _stack_arrays(tuples, dtype)
#    5037     stacked = np.empty(shape, dtype=dtype)
#    5038     for i, arr in enumerate(arrays):
# -> 5039         stacked[i] = _asarray_compat(arr)
#    5040
#    5041     return stacked, placement
#
# ValueError: could not broadcast input array from shape (4936) into shape (1235)

# %% [markdown]
# ### Feature Importance

# %%
features = pd.DataFrame({'feature_names': dat_cp.columns.values,
            'feature_importances': clf.feature_importances_})

features_vl = pd.DataFrame({'feature_names': dat_cp_vl.columns.values,
            'feature_importances': clf_vl.feature_importances_})

features_short = pd.DataFrame({'feature_names': data_short.columns.values,
            'feature_importances': clf_short.feature_importances_})

features_long = pd.DataFrame({'feature_names': data_long.columns.values,
            'feature_importances': clf_long.feature_importances_})

# %%
features_vl.sort_values(by='feature_importances', ascending=False).head(20)
# Out:
#                         feature_names  feature_importances
# 51                     Vertragslaenge             0.496273
# 5                           pi_median             0.034164
# 11                   piArticle_median             0.033870
# 10      piArticle_diff_max_min_normed             0.032661
# 43                 vArticle_activ_wks             0.032144
# 20       vArticle_diff_max_min_normed             0.028822
# 4              pi_diff_max_min_normed             0.026566
# 13               piPlusComment_median             0.022946
# 0               v_diff_max_min_normed             0.020100
# 6       piComment_diff_max_min_normed             0.019687
# 42                 vSection_activ_wks             0.017233
# 12  piPlusComment_diff_max_min_normed             0.016897
# 47             vPlusArticle_activ_wks             0.016712
# 21                    vArticle_median             0.014435
# 29                vPlusArticle_median             0.014136
# 34                        v_activ_wks             0.013338
# 30    vPlusMobile_diff_max_min_normed             0.012551
# 24       vDesktop_diff_max_min_normed             0.012202
# 1                            v_median             0.010602
# 25                    vDesktop_median             0.008245

# %%
features.sort_values(by='feature_importances', ascending=False).head(20)
# Out:
#                         feature_names  feature_importances
# 43                 vArticle_activ_wks             0.133559
# 5                           pi_median             0.069136
# 20       vArticle_diff_max_min_normed             0.065503
# 4              pi_diff_max_min_normed             0.047191
# 34                        v_activ_wks             0.046827
# 0               v_diff_max_min_normed             0.040547
# 47             vPlusArticle_activ_wks             0.037606
# 13               piPlusComment_median             0.032667
# 7                    piComment_median             0.032137
# 12  piPlusComment_diff_max_min_normed             0.031100
# 11                   piArticle_median             0.030546
# 21                    vArticle_median             0.028041
# 6       piComment_diff_max_min_normed             0.027132
# 39            piPlusComment_activ_wks             0.027093
# 10      piArticle_diff_max_min_normed             0.024137
# 28   vPlusArticle_diff_max_min_normed             0.023823
# 24       vDesktop_diff_max_min_normed             0.023658
# 45                 vDesktop_activ_wks             0.023308
# 23                     vMobile_median             0.020463
# 25                    vDesktop_median             0.018055

# %%
features_short.sort_values(by='feature_importances',ascending=False).head(20)
# Out:
#                         feature_names  feature_importances
# 43                 vArticle_activ_wks             0.087183
# 5                           pi_median             0.086677
# 12  piPlusComment_diff_max_min_normed             0.062513
# 4              pi_diff_max_min_normed             0.052538
# 13               piPlusComment_median             0.051434
# 7                    piComment_median             0.042925
# 34                        v_activ_wks             0.037691
# 20       vArticle_diff_max_min_normed             0.036323
# 28   vPlusArticle_diff_max_min_normed             0.036010
# 1                            v_median             0.034987
# 11                   piArticle_median             0.030161
# 25                    vDesktop_median             0.027760
# 44                  vMobile_activ_wks             0.026576
# 6       piComment_diff_max_min_normed             0.026305
# 22        vMobile_diff_max_min_normed             0.024318
# 47             vPlusArticle_activ_wks             0.023959
# 2           vPlus_diff_max_min_normed             0.021504
# 45                 vDesktop_activ_wks             0.019428
# 21                    vArticle_median             0.019413
# 0               v_diff_max_min_normed             0.018139

# %%
features_long.sort_values(by='feature_importances',ascending=False).head(20)
# Out:
#                         feature_names  feature_importances
# 43                 vArticle_activ_wks             0.130287
# 47             vPlusArticle_activ_wks             0.055161
# 5                           pi_median             0.053278
# 20       vArticle_diff_max_min_normed             0.052971
# 11                   piArticle_median             0.052926
# 4              pi_diff_max_min_normed             0.040209
# 21                    vArticle_median             0.037410
# 0               v_diff_max_min_normed             0.036407
# 28   vPlusArticle_diff_max_min_normed             0.036030
# 24       vDesktop_diff_max_min_normed             0.035204
# 34                        v_activ_wks             0.033065
# 10      piArticle_diff_max_min_normed             0.030575
# 7                    piComment_median             0.027005
# 12  piPlusComment_diff_max_min_normed             0.026261
# 13               piPlusComment_median             0.022898
# 1                            v_median             0.022895
# 39            piPlusComment_activ_wks             0.020147
# 25                    vDesktop_median             0.020010
# 19                    vSection_median             0.017491
# 23                     vMobile_median             0.016667

# %%
for idx, key in enumerate(keys):
    dat = dats[idx]['dat_abs_gauss_final'].drop(columns = ['Kuendigungsstatus','Vertragslaenge'])
    features = pd.DataFrame({'feature_names': dat.columns.values,
            'feature_importances': classifiers[key].feature_importances_})
    print(key)
    print(features.sort_values(by='feature_importances',ascending=False).head(20))
    print('')
# Out:
# dat_all
#               feature_names  feature_importances
# 43       vArticle_activ_wks             0.088751
# 4                   pi_mean             0.063634
# 21       vArticle_sd_normed             0.060064
# 1               v_sd_normed             0.055456
# 5              pi_sd_normed             0.048761
# 13  piPlusComment_sd_normed             0.048214
# 12       piPlusComment_mean             0.037706
# 24            vDesktop_mean             0.036552
# 10           piArticle_mean             0.035139
# 20            vArticle_mean             0.031748
# 47   vPlusArticle_activ_wks             0.031242
# 7       piComment_sd_normed             0.029271
# 29   vPlusArticle_sd_normed             0.028483
# 11      piArticle_sd_normed             0.027641
# 6            piComment_mean             0.027331
# 0                    v_mean             0.024553
# 3           vPlus_sd_normed             0.023576
# 25       vDesktop_sd_normed             0.022890
# 34              v_activ_wks             0.021571
# 28        vPlusArticle_mean             0.020877
#
# dat_long
#               feature_names  feature_importances
# 43       vArticle_activ_wks             0.089918
# 4                   pi_mean             0.061280
# 10           piArticle_mean             0.054476
# 21       vArticle_sd_normed             0.049702
# 20            vArticle_mean             0.049083
# 5              pi_sd_normed             0.040659
# 13  piPlusComment_sd_normed             0.038964
# 29   vPlusArticle_sd_normed             0.036984
# 24            vDesktop_mean             0.033572
# 6            piComment_mean             0.033469
# 47   vPlusArticle_activ_wks             0.032793
# 1               v_sd_normed             0.032505
# 7       piComment_sd_normed             0.032102
# 12       piPlusComment_mean             0.031860
# 11      piArticle_sd_normed             0.026199
# 0                    v_mean             0.025130
# 39  piPlusComment_activ_wks             0.022021
# 25       vDesktop_sd_normed             0.021509
# 33   vPlusDesktop_sd_normed             0.019692
# 45       vDesktop_activ_wks             0.019650
#
# dat_short
#               feature_names  feature_importances
# 4                   pi_mean             0.084083
# 12       piPlusComment_mean             0.070013
# 43       vArticle_activ_wks             0.057165
# 20            vArticle_mean             0.055574
# 10           piArticle_mean             0.048557
# 0                    v_mean             0.048166
# 21       vArticle_sd_normed             0.046436
# 6            piComment_mean             0.045581
# 5              pi_sd_normed             0.037628
# 1               v_sd_normed             0.035248
# 24            vDesktop_mean             0.034114
# 13  piPlusComment_sd_normed             0.033441
# 11      piArticle_sd_normed             0.029043
# 19       vSection_sd_normed             0.027717
# 28        vPlusArticle_mean             0.026322
# 47   vPlusArticle_activ_wks             0.025905
# 34              v_activ_wks             0.025683
# 29   vPlusArticle_sd_normed             0.025346
# 45       vDesktop_activ_wks             0.024499
# 7       piComment_sd_normed             0.021544
#
# dat_all_wBehav
#                feature_names  feature_importances
# 111       vArticle_activ_wks             0.104601
# 12                   pi_mean             0.055892
# 13              pi_sd_normed             0.033945
# 61        vArticle_sd_normed             0.033547
# 60             vArticle_mean             0.030779
# 115   vPlusArticle_activ_wks             0.029498
# 1                v_sd_normed             0.028486
# 102              v_activ_wks             0.025904
# 30            piArticle_mean             0.025706
# 0                     v_mean             0.024977
# 18            piComment_mean             0.024798
# 72             vDesktop_mean             0.022026
# 19       piComment_sd_normed             0.021927
# 37   piPlusComment_sd_normed             0.021767
# 107  piPlusComment_activ_wks             0.021315
# 36        piPlusComment_mean             0.019056
# 85    vPlusArticle_sd_normed             0.017065
# 84         vPlusArticle_mean             0.017031
# 7            vPlus_sd_normed             0.015388
# 62   vArticle_zsc_usr_behav1             0.013898
#
# dat_long_wBehav
#                feature_names  feature_importances
# 111       vArticle_activ_wks             0.102432
# 12                   pi_mean             0.058934
# 30            piArticle_mean             0.047997
# 60             vArticle_mean             0.033773
# 115   vPlusArticle_activ_wks             0.031945
# 1                v_sd_normed             0.030030
# 36        piPlusComment_mean             0.028859
# 72             vDesktop_mean             0.027665
# 37   piPlusComment_sd_normed             0.025336
# 13              pi_sd_normed             0.024165
# 0                     v_mean             0.023383
# 61        vArticle_sd_normed             0.022747
# 19       piComment_sd_normed             0.021791
# 107  piPlusComment_activ_wks             0.020872
# 102              v_activ_wks             0.019111
# 18            piComment_mean             0.018669
# 73        vDesktop_sd_normed             0.015913
# 54             vSection_mean             0.015254
# 77   vDesktop_zsc_usr_behav4             0.014102
# 84         vPlusArticle_mean             0.012625
#
# dat_short_wBehav
#               feature_names  feature_importances
# 12                  pi_mean             0.071103
# 36       piPlusComment_mean             0.067888
# 111      vArticle_activ_wks             0.060134
# 60            vArticle_mean             0.052733
# 30           piArticle_mean             0.043289
# 61       vArticle_sd_normed             0.041535
# 0                    v_mean             0.037055
# 115  vPlusArticle_activ_wks             0.035599
# 84        vPlusArticle_mean             0.034510
# 18           piComment_mean             0.033784
# 13             pi_sd_normed             0.028607
# 72            vDesktop_mean             0.025931
# 102             v_activ_wks             0.024558
# 1               v_sd_normed             0.021383
# 19      piComment_sd_normed             0.021177
# 85   vPlusArticle_sd_normed             0.021002
# 112       vMobile_activ_wks             0.020086
# 113      vDesktop_activ_wks             0.018172
# 31      piArticle_sd_normed             0.016703
# 66             vMobile_mean             0.014901

# %% [markdown]
# ### FIND DECISION RULES: Make several trees in order to extract boundaries

# %%
# function to plot n decision trees for subsets of data 
def plot_trees(dat, label, word, n=10):
    for i in range(1,(n+1)):
        # split test, train data
        dat_train, dat_test, label_train, label_test = train_test_split(dat, label, 
                                                                        test_size=0.2, random_state=3*i)


        clf = tree.DecisionTreeClassifier(max_depth=4)
        clf = clf.fit(dat_train, label_train)
        
        features = dat_train.columns.values
        dot_data = tree.export_graphviz(clf, out_file=None, 
                                        feature_names=features,
                                        class_names = True,
                                        filled=True, rounded=True)

        graph = graphviz.Source(dot_data)
        # file name
        fname = 'decision_trees/tree_'+ word +str(i).zfill(2)
        graph.render(fname)

# %%
from sklearn import tree
import graphviz 
from sklearn.model_selection import train_test_split

# prepare data
data_long, data_short = dat_long_wBehav['dat_abs_median_final'], dat_short_wBehav['dat_abs_median_final']
label_long, label_short = data_long['Kuendigungsstatus'], data_short['Kuendigungsstatus']
data_long, data_short = data_long.drop(columns = ['Kuendigungsstatus','Vertragslaenge']),\
                        data_short.drop(columns = ['Kuendigungsstatus','Vertragslaenge'])



# plot generation of trees
# first generation: all variables
plot_trees(data_short,label_short, 'shortVL_01',n=5)
plot_trees(data_long,label_long, 'longVL_01',n=5)

# second generation: 'vArticle_activ_weeks' is not included
data_short_02 = data_short.drop(columns=['vArticle_activ_wks','v_activ_wks'])
data_long_02 = data_long.drop(columns=['vArticle_activ_wks','v_activ_wks'])

plot_trees(data_short_02,label_short, 'shortVL_02',n=5)
plot_trees(data_long_02,label_long, 'longVL_02',n=5)

# third generation
data_short_03 = data_short_02.drop(columns=['piPlusComment_activ_wks'])
data_long_03 = data_long_02.drop(columns=['vPlusArticle_activ_wks'])

plot_trees(data_short_03,label_short, 'shortVL_03',n=5)
plot_trees(data_long_03,label_long, 'longVL_03',n=5)

# fourth generation
data_short_04 = data_short_03.drop(columns=['vPlusArticle_activ_wks','vPlus_activ_wks'])
data_long_04 = data_long_03.drop(columns=['piPlusComment_activ_wks'])

plot_trees(data_short_04,label_short, 'shortVL_04',n=5)
plot_trees(data_long_04,label_long, 'longVL_04',n=5)

# fifth generation
data_short_05 = data_short_04.drop(columns=['piComment_activ_wks'])
plot_trees(data_short_05,label_short, 'shortVL_05',n=5)
